# %% [markdown]
# <a href="https://colab.research.google.com/github/tammavarapu/tensorflow_exp/blob/main/Facies_Classification_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('training_data.csv')

# %%
data = df.copy()

# %%
data.head(10)
# Out:
#    Facies Formation  Well Name   Depth  ...   PHIND   PE  NM_M  RELPOS
# 0       3     A1 SH  SHRIMPLIN  2793.0  ...  11.915  4.6     1   1.000
# 1       3     A1 SH  SHRIMPLIN  2793.5  ...  12.565  4.1     1   0.979
# 2       3     A1 SH  SHRIMPLIN  2794.0  ...  13.050  3.6     1   0.957
# 3       3     A1 SH  SHRIMPLIN  2794.5  ...  13.115  3.5     1   0.936
# 4       3     A1 SH  SHRIMPLIN  2795.0  ...  13.300  3.4     1   0.915
# 5       3     A1 SH  SHRIMPLIN  2795.5  ...  13.385  3.6     1   0.894
# 6       3     A1 SH  SHRIMPLIN  2796.0  ...  13.930  3.7     1   0.872
# 7       3     A1 SH  SHRIMPLIN  2796.5  ...  13.920  3.5     1   0.830
# 8       3     A1 SH  SHRIMPLIN  2797.0  ...  13.980  3.4     1   0.809
# 9       3     A1 SH  SHRIMPLIN  2797.5  ...  14.220  3.5     1   0.787
#
# [10 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3232 entries, 0 to 3231
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Facies     3232 non-null   int64
#  1   Formation  3232 non-null   object
#  2   Well Name  3232 non-null   object
#  3   Depth      3232 non-null   float64
#  4   GR         3232 non-null   float64
#  5   ILD_log10  3232 non-null   float64
#  6   DeltaPHI   3232 non-null   float64
#  7   PHIND      3232 non-null   float64
#  8   PE         3232 non-null   float64
#  9   NM_M       3232 non-null   int64
#  10  RELPOS     3232 non-null   float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 277.9+ KB

# %%
data.isna().sum()
# Out:
# Facies       0
# Formation    0
# Well Name    0
# Depth        0
# GR           0
# ILD_log10    0
# DeltaPHI     0
# PHIND        0
# PE           0
# NM_M         0
# RELPOS       0
# dtype: int64

# %%
data.describe()
# Out:
#             Facies        Depth  ...         NM_M       RELPOS
# count  3232.000000  3232.000000  ...  3232.000000  3232.000000
# mean      4.422030  2875.824567  ...     1.498453     0.520287
# std       2.504243   131.006274  ...     0.500075     0.286792
# min       1.000000  2573.500000  ...     1.000000     0.010000
# 25%       2.000000  2791.000000  ...     1.000000     0.273000
# 50%       4.000000  2893.500000  ...     1.000000     0.526000
# 75%       6.000000  2980.000000  ...     2.000000     0.767250
# max       9.000000  3122.500000  ...     2.000000     1.000000
#
# [8 rows x 9 columns]

# %%
test_well = data[data['Well Name'] == 'SHANKLE']

# %%
test_well.head(5)
# Out:
#      Facies Formation Well Name   Depth  ...   PHIND   PE  NM_M  RELPOS
# 471       2     A1 SH   SHANKLE  2774.5  ...  18.685  2.9     1   1.000
# 472       2     A1 SH   SHANKLE  2775.0  ...  16.745  3.2     1   0.984
# 473       2     A1 SH   SHANKLE  2775.5  ...  14.105  3.2     1   0.968
# 474       2     A1 SH   SHANKLE  2776.0  ...  13.385  3.4     1   0.952
# 475       2     A1 SH   SHANKLE  2776.5  ...  13.345  3.4     1   0.935
#
# [5 rows x 11 columns]

# %%
 final_data = data[data['Well Name'] != 'SHANKLE']

# %%
final_data.head(5)
# Out:
#    Facies Formation  Well Name   Depth  ...   PHIND   PE  NM_M  RELPOS
# 0       3     A1 SH  SHRIMPLIN  2793.0  ...  11.915  4.6     1   1.000
# 1       3     A1 SH  SHRIMPLIN  2793.5  ...  12.565  4.1     1   0.979
# 2       3     A1 SH  SHRIMPLIN  2794.0  ...  13.050  3.6     1   0.957
# 3       3     A1 SH  SHRIMPLIN  2794.5  ...  13.115  3.5     1   0.936
# 4       3     A1 SH  SHRIMPLIN  2795.0  ...  13.300  3.4     1   0.915
#
# [5 rows x 11 columns]

# %%
final_data.columns
# Out:
# Index(['Facies', 'Formation', 'Well Name', 'Depth', 'GR', 'ILD_log10',
#        'DeltaPHI', 'PHIND', 'PE', 'NM_M', 'RELPOS'],
#       dtype='object')

# %%
features = ['GR', 'ILD_log10','DeltaPHI', 'PHIND', 'PE', 'NM_M', 'RELPOS']

# %%
feature_vector = final_data[features]

# %%
facies_label = final_data['Facies']

# %%
import seaborn as sns

# %%
sns.pairplot(feature_vector[['GR', 'ILD_log10','DeltaPHI', 'PHIND', 'PE']])

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler().fit(feature_vector)

# %%
scaled_features = scaler.transform(feature_vector)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_cv,y_train,y_cv =train_test_split(scaled_features,facies_label,test_size=0.05,random_state=42)

# %%
y_test = test_well['Facies']

# %%
well_features = test_well.drop(['Facies','Formation','Well Name','Depth'], axis=1)

# %%
X_test = scaler.transform(well_features)

# %%
from sklearn import svm

# %%
clf = svm.SVC(C=10,gamma=1)

# %%
clf.fit(X_train,y_train)
# Out:
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf', max_iter=-1,
#     probability=False, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
y_test = test_well['Facies']

# %%
well_features = test_well.drop(['Facies', 'Formation', 'Well Name', 'Depth'], axis=1)

# %%
X_test = scaler.transform(well_features)

# %%
y_pred = clf.predict(X_test) 
test_well['Prediction'] = y_pred
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
target_names = ['SS', 'CSiS', 'FSiS', 'SiSh', 'MS', 'WS', 'D','PS', 'BS']

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#           SS       0.30      0.08      0.12        89
#         CSiS       0.36      0.72      0.48        89
#         FSiS       0.62      0.54      0.58       117
#         SiSh       0.25      0.29      0.27         7
#           MS       0.17      0.11      0.13        19
#           WS       0.66      0.54      0.59        71
#            D       0.71      0.29      0.42        17
#           PS       0.41      0.60      0.49        40
#           BS       0.00      0.00      0.00         0
#
#     accuracy                           0.46       449
#    macro avg       0.39      0.35      0.34       449
# weighted avg       0.47      0.46      0.43       449
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...
